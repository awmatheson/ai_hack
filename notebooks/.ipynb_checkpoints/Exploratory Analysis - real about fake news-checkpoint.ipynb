# %%
import pandas as pd
from textblob import TextBlob
import os

import sys
reload(sys)
sys.setdefaultencoding("utf-8")

# %%
fake_news = pd.read_csv('fake.csv')
print(fake_news)

# %%
bias_df = fake_news.loc[fake_news['type'] == 'bias']
bs_df = fake_news.loc[fake_news['type'] == 'bs']

# %%
bs_df
# Out:
#                                            uuid  ord_in_thread  \
# 59     b9af57aaf67e5894ea9cee78d8f646aecaa0ebd9              0
# 60     03905a0f06cb711190aad3934af253a0e1c00a83              1
# 61     42c16d3818e64ff4632409cafd309c22df530ac1              2
# 62     336f5dfbea5f263dbdd6ec9be9d1d94d255caa1f              3
# 63     ea086a28e0bbafcd9fbaabd728920337371d4876              4
# 64     6fad6edc4156d92153a9a7a0d66f7ae59b98760c              5
# 65     30026d6f4721bb93578dffe88ee680e1dcbf20c8              6
# 66     4b9eb00294cc3efea62d55aa972b8218b588b55e              4
# 67     11ecd71be0955967a9058366b7bee2499dbc3e95              5
# 68     269e89072d73ae89a8645199b121aaa497460f40              6
# 69     a3c854d3f9deceb87d031300016128124040c9a7              0
# 70     3ab296a353b298c9cae5042219c8c03c8233ca0b              1
# 71     7dfe3b0a85d4f96a3d024615267629ee56d9846f              2
# 72     4384d62eb60d6da437e335573ff4c61bda9ed4fa              3
# ...

# %%
bias_df['subjectivity'] = bias_df['text'].apply(lambda x: TextBlob(x).sentiment[1])
bias_df['polarity'] = bias_df['text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
bs_df['subjectivity'] = bs_df['text'].apply(lambda x: TextBlob(x).sentiment[1])
bs_df['polarity'] = bs_df['text'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
bias_df[['subjectivity','polarity','text','title']]
# Out:
#        subjectivity  polarity  \
# 0          0.405000  0.100000
# 1          0.376488  0.054771
# 2          0.533667  0.183000
# 3          0.916667  0.000000
# 4          0.448784  0.176472
# 5          0.668421 -0.264098
# 6          0.521732 -0.012089
# 7          0.299206  0.003355
# 8          0.379149  0.106304
# 9          0.699851 -0.188244
# 10         0.000000  0.000000
# 11         0.487406  0.083628
# 12         0.408502  0.179261
# 13         0.594363  0.017645
# 14         1.000000  0.800000
# 15         0.670909  0.487273
# 16         1.000000  0.800000
# 17         0.468153  0.094250
# 18         0.444990  0.132937
# 19         0.520762  0.179432
# 20         0.344650  0.138718
# 21         0.658333 -0.397917
# 22         0.385185  0.076852
# 23         0.337764  0.008916
# 24         0.452315  0.184491
# 25         0.000000  0.000000
# 26         0.590950 -0.022939
# 27         0.357645  0.142975
# 28         0.398653  0.058670
# 29         0.464127  0.172302
# ...

# %%
bias_df.describe()
# Out:
#        ord_in_thread   domain_rank  spam_score  replies_count  \
# count     443.000000    442.000000  443.000000     443.000000
# mean        3.367946   6955.246606    0.029172       6.033860
# std        10.266034   7661.747350    0.131427      15.630381
# min         0.000000    829.000000    0.000000       0.000000
# 25%         0.000000   1550.000000    0.000000       0.000000
# 50%         0.000000   4617.000000    0.000000       0.000000
# 75%         0.000000  15846.000000    0.000000       0.000000
# max        69.000000  25689.000000    0.998000      89.000000
#
#        participants_count       likes    comments      shares  subjectivity  \
# count          443.000000  443.000000  443.000000  443.000000    443.000000
# mean             6.415350   34.643341    0.029345   34.643341      0.421011
# std             14.429543  154.611699    0.364172  154.611699      0.195627
# min              0.000000    0.000000    0.000000    0.000000      0.000000
# ...

# %%
bs_df.describe()
# Out:
#        ord_in_thread   domain_rank    spam_score  replies_count  \
# count   11492.000000   7457.000000  11492.000000   11492.000000
# mean        0.863122  41492.913772      0.026973       1.314306
# std         6.550432  26982.855627      0.124810       9.733963
# min         0.000000    486.000000      0.000000       0.000000
# 25%         0.000000  19375.000000      0.000000       0.000000
# 50%         0.000000  36674.000000      0.000000       0.000000
# 75%         0.000000  62759.000000      0.000000       0.000000
# max       100.000000  98679.000000      1.000000     309.000000
#
#        participants_count         likes      comments        shares  \
# count        11492.000000  11492.000000  11492.000000  11492.000000
# mean             1.644448      6.179255      0.042029      6.179255
# std              6.679226     60.483221      0.876734     60.483221
# min              0.000000      0.000000      0.000000      0.000000
# ...

# %%
for file_name in [os.path.abspath(name) for name in os.listdir(".") if os.path.isdir(name)]:
    print file_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-b09a013dc2c7> in <module>()
# ----> 1 for file_name in [os.path.abspath(name) for name in os.listdir(".") if os.path.isdir(name)]:
#       2     print file_name
#
# NameError: name 'os' is not defined
